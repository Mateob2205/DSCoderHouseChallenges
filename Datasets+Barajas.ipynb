# %%
import pandas as pd
pd.read_csv('Customers.csv')
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
pd.read_csv('BigmacPrice.csv')
# Out:
#                                                     date,"currency_code","name","local_price","dollar_ex","dollar_price"
# 2000-04-01 ARS Argentina            2.50     1                                                   2.50
#            AUD Australia            2.59     1                                                   2.59
#            BRL Brazil               2.95     1                                                   2.95
#            GBP Britain              1.90     1                                                   1.90
#            CAD Canada               2.85     1                                                   2.85
# ...                                                                                               ...
# 2022-07-01 AED United Arab Emirates 18.00    3                                                   6.00
#            USD United States        5.15     1                                                   5.15
# ...

# %%
data = pd.read_csv('application_record.csv')
data
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5010121           M            Y               Y             0
# 1       5010122           M            Y               Y             0
# 2       5010123           M            Y               Y             0
# 3       5010124           F            Y               Y             1
# 4       5010126           F            N               Y             2
# ...         ...         ...          ...             ...           ...
# 202885  5918700           F            N               Y             0
# 202886  6507558           F            N               Y             0
# 202887  6507559           F            N               Y             0
# 202888  6507560           F            N               Y             0
# 202889  6507561           F            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
mpl.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
mpl.style.use('bmh')

# %%
#Seaborn 
sns.histplot(data=data, x="NAME_INCOME_TYPE", hue="NAME_INCOME_TYPE", multiple="stack")
# Out:
# <Axes: xlabel='NAME_INCOME_TYPE', ylabel='Count'>

# %%
sns.displot(data=data, x="NAME_INCOME_TYPE", hue="NAME_INCOME_TYPE", col="NAME_INCOME_TYPE")

# %%
sns.scatterplot(data=data, x="AMT_INCOME_TOTAL", y="CNT_FAM_MEMBERS", hue="NAME_INCOME_TYPE")
# Out:
# <Axes: xlabel='AMT_INCOME_TOTAL', ylabel='CNT_FAM_MEMBERS'>

# %%
sns.scatterplot(data=data, x="AMT_INCOME_TOTAL", y="CNT_FAM_MEMBERS")
# Out:
# <Axes: xlabel='AMT_INCOME_TOTAL', ylabel='CNT_FAM_MEMBERS'>

# %%
 sns.barplot(x="CODE_GENDER", y="AMT_INCOME_TOTAL", hue="NAME_INCOME_TYPE", data=data)
# Out:
# <Axes: xlabel='CODE_GENDER', ylabel='AMT_INCOME_TOTAL'>

# %%
sns.set_theme(style="whitegrid")
# Axis-level
ax = sns.boxplot(x=data["AMT_INCOME_TOTAL"])

# %%
#Matplotlib
fig, ax = plt.subplots(figsize=(8, 5))
ax.boxplot(x=data.AMT_INCOME_TOTAL,)
ax.set_title('Boxplot de Solicitantes')
ax.set_xlabel('Tiempo')
ax.set_ylabel('Monto total Ingresos')
# Out:
# Text(0, 0.5, 'Monto total Ingresos')

# %%
pd.value_counts(data['CODE_GENDER'])
# Out:
# F    136803
# M     66087
# Name: CODE_GENDER, dtype: int64

# %%
100 * data['CODE_GENDER'].value_counts() / len(data['CODE_GENDER'])
# Out:
# F    67.427177
# M    32.572823
# Name: CODE_GENDER, dtype: float64

# %%
plot = data['CODE_GENDER'].value_counts().plot(kind='bar',
                                            title='Género')

# %%
plot = data['CODE_GENDER'].value_counts().plot(kind='pie', autopct='%.2f', 
                                            figsize=(6, 6),
                                            title='Pasajeros del Titanic')
